# %% [markdown]
# A2a Research Assignment 02 - Part 1
#
# Import packages needed

# %%
import datetime
import time
import numpy as np
import pandas as pd
from packaging import version
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.7.0

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.7.0

# %% [markdown]
# Mount Google Drive to Colab Environment

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %% [markdown]
# Functions for Research Assignment

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# Loading cifar10 Dataset
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %% [markdown]
# Tuple of Numpy arrays: (x_train, y_train), (x_test, y_test).
#
# x_train, x_test: uint8 arrays of color image data with shapes (num_samples, 32, 32).
#
# y_train, y_test: uint8 arrays of digit labels (integers in range 0-9)
#
# EDA Training and Test Datasets
#
# Imported 50000 examples for training and 10000 examples for test
#
# Imported 50000 labels for training and 10000 labels for test

# %%
print('train_images:\t{}'.format(x_train.shape))
print('train_labels:\t{}'.format(y_train.shape))
print('test_images:\t\t{}'.format(x_test.shape))
print('test_labels:\t\t{}'.format(y_test.shape))
# Out:
# train_images:	(50000, 32, 32, 3)
# train_labels:	(50000, 1)
# test_images:		(10000, 32, 32, 3)
# test_labels:		(10000, 1)

# %% [markdown]
# Review labels for training dataset

# %%
print("First ten labels training dataset:\n {}\n".format(y_train[0:10]))
print("This output the numeric label, need to convert to item description")
# Out:
# First ten labels training dataset:
#  [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]
#
# This output the numeric label, need to convert to item description

# %% [markdown]
# Plot Examples

# %%
def get_three_classes(x, y):
    def indices_of(class_id):
        indices, _ = np.where(y == float(class_id))
        return indices

    indices = np.concatenate([indices_of(0), indices_of(1), indices_of(2)], axis=0)
    
    x = x[indices]
    y = y[indices]
    
    count = x.shape[0]
    indices = np.random.choice(range(count), count, replace=False)
    
    x = x[indices]
    y = y[indices]
    
    y = tf.keras.utils.to_categorical(y)
    
    return x, y

# %%
(train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %%
x_preview, y_preview = get_three_classes(train_images, train_labels)
x_preview, y_preview = get_three_classes(test_images, test_labels)

# %%
class_names_preview = ['aeroplane', 'car', 'bird']

def show_random_examples(x, y, p):
    indices = np.random.choice(range(x.shape[0]), 10, replace=False)
    
    x = x[indices]
    y = y[indices]
    p = p[indices]
    
    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(class_names_preview[np.argmax(p[i])], color=col)
    plt.show()

show_random_examples(x_preview, y_preview, y_preview)

# %% [markdown]
# Preprocessing Data for Model Development
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# Label	Class_
#
# 0	airplane
#
# 1	automobile
#
# 2	bird
#
# 3	cat
#
# 4	deer
#
# 5	dog
#
# 6	frog
#
# 7	horse
#
# 8	ship
#
# 9	truck

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

# %% [markdown]
# Create Validation Data Set

# %%
x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(x_train
                                                                              ,y_train
                                                                              ,test_size=.1
                                                                              ,random_state=42
                                                                              ,shuffle=True)

# %% [markdown]
# Confirm Datasets {Train, Validation, Test}

# %%
print(x_train_split.shape, x_valid_split.shape, x_test.shape)
# Out:
# (45000, 32, 32, 3) (5000, 32, 32, 3) (10000, 32, 32, 3)

# %% [markdown]
# Rescale Examples {Train, Validation, Test}
#
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255
#
# Each element in each example is a pixel value
#
# Pixel values range from 0 to 255
#
# 0 = black
#
# 255 = white

# %%
x_train_norm = x_train_split/255

x_valid_norm = x_valid_split/255

x_test_norm = x_test/255

# %% [markdown]
# Build CNN Model
#
# We use a Sequential class defined in Keras to create our model.
#
# The first 9 layers Conv2D MaxPooling, Dropout handle feature learning.
#
# The last 3 layers, handle classification

# %%
model = models.Sequential()
model.add(layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu,input_shape=(32, 32, 3)))
model.add(layers.MaxPool2D((2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Flatten())
model.add(layers.BatchNormalization())
model.add(layers.Dense(units=384, activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.L2(0.001)))
model.add(layers.Dense(units=10, activation=tf.nn.softmax))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 30, 30, 128)       3584
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 15, 15, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       295168
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dense_2 (Dense)             (None, 384)               786816
#
#  dense_3 (Dense)             (None, 10)                3850
#
# =================================================================
# Total params: 2,277,770
# Trainable params: 2,273,674
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "CIFAR10.png", show_shapes=True)

# %% [markdown]
# **Compiling the model**
#
# In addition to setting up our model architecture, we also need to define which algorithm should the model use in order to optimize the weights and biases as per the given data. We will use stochastic gradient descent.
#
# We also need to define a loss function. Think of this function as the difference between the predicted outputs and the actual outputs given in the dataset. This loss needs to be minimised in order to have a higher model accuracy. That's what the optimization algorithm essentially does - it minimises the loss during model training. For our multi-class classification problem, categorical cross entropy is commonly used.
#
# Finally, we will use the accuracy during training as a metric to keep track of as the model trains.

# %%
model.compile(optimizer='Adagrad', 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
history = model.fit(x_train_norm
                    ,y_train_split
                    ,epochs=200
                    ,batch_size=512
                    ,validation_data=(x_valid_norm, y_valid_split)
                    ,callbacks=[
                    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
                    tf.keras.callbacks.ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/models/model_{val_accuracy:.4f}.h5', save_best_only=True,
                                        save_weights_only=False, monitor='val_accuracy')]                                                                                                           
                   )
# Out:
# Epoch 1/200
# 88/88 [==============================] - 4s 41ms/step - loss: 3.1038 - accuracy: 0.1393 - val_loss: 2.9376 - val_accuracy: 0.1170
# Epoch 2/200
# 88/88 [==============================] - 3s 37ms/step - loss: 2.7841 - accuracy: 0.2098 - val_loss: 2.9233 - val_accuracy: 0.1028
# Epoch 3/200
# 88/88 [==============================] - 3s 37ms/step - loss: 2.6554 - accuracy: 0.2557 - val_loss: 2.9000 - val_accuracy: 0.1072
# Epoch 4/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.5829 - accuracy: 0.2823 - val_loss: 2.8579 - val_accuracy: 0.1324
# Epoch 5/200
# 88/88 [==============================] - 3s 39ms/step - loss: 2.5279 - accuracy: 0.3071 - val_loss: 2.8076 - val_accuracy: 0.1544
# Epoch 6/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.4849 - accuracy: 0.3251 - val_loss: 2.7467 - val_accuracy: 0.1908
# Epoch 7/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.4472 - accuracy: 0.3396 - val_loss: 2.7063 - val_accuracy: 0.2084
# Epoch 8/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.4125 - accuracy: 0.3569 - val_loss: 2.6538 - val_accuracy: 0.2398
# Epoch 9/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.3839 - accuracy: 0.3662 - val_loss: 2.6247 - val_accuracy: 0.2596
# Epoch 10/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.3559 - accuracy: 0.3770 - val_loss: 2.5994 - val_accuracy: 0.2688
# Epoch 11/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.3288 - accuracy: 0.3831 - val_loss: 2.5523 - val_accuracy: 0.2876
# Epoch 12/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.3072 - accuracy: 0.3917 - val_loss: 2.5289 - val_accuracy: 0.2988
# Epoch 13/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.2795 - accuracy: 0.4030 - val_loss: 2.4755 - val_accuracy: 0.3162
# Epoch 14/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.2617 - accuracy: 0.4114 - val_loss: 2.4699 - val_accuracy: 0.3188
# Epoch 15/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.2407 - accuracy: 0.4189 - val_loss: 2.4286 - val_accuracy: 0.3328
# Epoch 16/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.2222 - accuracy: 0.4234 - val_loss: 2.4104 - val_accuracy: 0.3414
# Epoch 17/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.2035 - accuracy: 0.4338 - val_loss: 2.3864 - val_accuracy: 0.3484
# Epoch 18/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.1883 - accuracy: 0.4398 - val_loss: 2.3664 - val_accuracy: 0.3530
# Epoch 19/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.1722 - accuracy: 0.4438 - val_loss: 2.3403 - val_accuracy: 0.3628
# Epoch 20/200
# 88/88 [==============================] - 3s 37ms/step - loss: 2.1596 - accuracy: 0.4482 - val_loss: 2.3370 - val_accuracy: 0.3622
# Epoch 21/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.1442 - accuracy: 0.4538 - val_loss: 2.3239 - val_accuracy: 0.3692
# Epoch 22/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.1319 - accuracy: 0.4577 - val_loss: 2.3119 - val_accuracy: 0.3826
# Epoch 23/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.1214 - accuracy: 0.4645 - val_loss: 2.2827 - val_accuracy: 0.3858
# Epoch 24/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.1066 - accuracy: 0.4687 - val_loss: 2.2838 - val_accuracy: 0.3880
# Epoch 25/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.0981 - accuracy: 0.4710 - val_loss: 2.2634 - val_accuracy: 0.3942
# Epoch 26/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.0881 - accuracy: 0.4748 - val_loss: 2.2500 - val_accuracy: 0.4040
# Epoch 27/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.0781 - accuracy: 0.4782 - val_loss: 2.2307 - val_accuracy: 0.4072
# Epoch 28/200
# 88/88 [==============================] - 3s 37ms/step - loss: 2.0699 - accuracy: 0.4781 - val_loss: 2.2373 - val_accuracy: 0.4064
# Epoch 29/200
# 88/88 [==============================] - 3s 37ms/step - loss: 2.0632 - accuracy: 0.4833 - val_loss: 2.2431 - val_accuracy: 0.4056
# Epoch 30/200
# 88/88 [==============================] - 3s 38ms/step - loss: 2.0514 - accuracy: 0.4876 - val_loss: 2.1985 - val_accuracy: 0.4194
# Epoch 31/200
# 88/88 [==============================] - 3s 37ms/step - loss: 2.0422 - accuracy: 0.4913 - val_loss: 2.2058 - val_accuracy: 0.4158
# Epoch 32/200
# 88/88 [==============================] - 3s 37ms/step - loss: 2.0361 - accuracy: 0.4951 - val_loss: 2.2035 - val_accuracy: 0.4162
# Epoch 33/200
# 88/88 [==============================] - 3s 37ms/step - loss: 2.0235 - accuracy: 0.4984 - val_loss: 2.2006 - val_accuracy: 0.4170

# %% [markdown]
# **Validation Data**
#
# Data on which to evaluate the loss and any model metrics at the end of each epoch
#
# The model will not be trained on this data
#
# **Evaluate the model**
#
# In order to ensure that this is not a simple "memorization" by the machine, we should evaluate the performance on the test set.
#
# This is easy to do, we simply use the evaluate method on our model.

# %%
loss, accuracy = model.evaluate(x_test_norm, y_test)
print('test set accuracy: ', accuracy * 100)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 2.1927 - accuracy: 0.4231
# test set accuracy:  42.30999946594238

# %% [markdown]
# **Predictions**

# %%
preds = model.predict(x_test_norm)
print('shape of preds: ', preds.shape)
# Out:
# shape of preds:  (10000, 10)

# %% [markdown]
# **Plotting Performance Metrics**
#
# We use Matplotlib to create 2 plots--displaying the training and validation loss (resp. accuracy) for each (training) epoch side by side.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#      loss  accuracy  val_loss  val_accuracy
# 28  2.063     0.483     2.243         0.406
# 29  2.051     0.488     2.199         0.419
# 30  2.042     0.491     2.206         0.416
# 31  2.036     0.495     2.204         0.416
# 32  2.023     0.498     2.201         0.417

# %%
losses = history.history['loss']
accs = history.history['accuracy']
val_losses = history.history['val_loss']
val_accs = history.history['val_accuracy']
epochs = len(losses)

# %%
plt.figure(figsize=(16, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# Confusion matrices
#
# Using both sklearn.metrics. Then we visualize the confusion matrix and see what that tells us.

# %%
pred1= model.predict(x_test_norm)
pred1=np.argmax(pred1, axis=1)

# %%
print_validation_report(y_test, pred1)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.54      0.01      0.03      1000
#            1       0.00      0.00      0.00      1000
#            2       0.06      0.01      0.02      1000
#            3       0.00      0.00      0.00      1000
#            4       0.10      0.99      0.18      1000
#            5       0.00      0.00      0.00      1000
#            6       0.14      0.00      0.01      1000
#            7       0.00      0.00      0.00      1000
#            8       0.00      0.00      0.00      1000
#            9       0.15      0.00      0.00      1000
#
#     accuracy                           0.10     10000
#    macro avg       0.10      0.10      0.02     10000
# weighted avg       0.10      0.10      0.02     10000
#
# Accuracy Score: 0.1022
# Root Mean Square Error: 2.9166076184499006
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_confusion_matrix(y_test,pred1)

# %% [markdown]
# Load HDF5 Model Format

# %%
model = tf.keras.models.load_model('/content/gdrive/My Drive/Colab Notebooks/models/model_0.4194.h5')

# %%
preds = model.predict(x_test_norm)

preds.shape
# Out:
# (10000, 10)

# %% [markdown]
# **Predictions**

# %%
cm = sns.light_palette((260, 75, 60), input="husl", as_cmap=True)

df = pd.DataFrame(preds[0:20], columns = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])
df.style.format("{:.2%}").background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_53ef5_row0_col0, #T_53ef5_row0_col9, #T_53ef5_row2_col6, #T_53ef5_row5_col0, #T_53ef5_row5_col7, #T_53ef5_row9_col3, #T_53ef5_row17_col9, #T_53ef5_row19_col5, #T_53ef5_row19_col7 {
#   background-color: #eeeff2;
#   color: #000000;
# }
# #T_53ef5_row0_col1, #T_53ef5_row8_col8, #T_53ef5_row9_col5, #T_53ef5_row10_col1, #T_53ef5_row12_col1, #T_53ef5_row12_col8, #T_53ef5_row16_col8, #T_53ef5_row17_col1, #T_53ef5_row18_col5 {
#   background-color: #f0f0f2;
#   color: #000000;
# }
# #T_53ef5_row0_col2 {
#   background-color: #b8c2eb;
#   color: #000000;
# }
# #T_53ef5_row0_col3 {
#   background-color: #b3bdeb;
#   color: #000000;
# }
# #T_53ef5_row0_col4 {
#   background-color: #d1d6ee;
#   color: #000000;
# }
# #T_53ef5_row0_col5 {
#   background-color: #dee1f0;
#   color: #000000;
# }
# #T_53ef5_row0_col6, #T_53ef5_row7_col2 {
#   background-color: #93a3e7;
#   color: #f1f1f1;
# }
# #T_53ef5_row0_col7, #T_53ef5_row0_col8, #T_53ef5_row2_col5, #T_53ef5_row2_col7, #T_53ef5_row3_col3, #T_53ef5_row4_col7, #T_53ef5_row7_col5, #T_53ef5_row7_col7, #T_53ef5_row9_col7, #T_53ef5_row10_col9 {
#   background-color: #efeff2;
#   color: #000000;
# }
# #T_53ef5_row1_col0, #T_53ef5_row1_col1 {
#   background-color: #afbaea;
#   color: #000000;
# }
# #T_53ef5_row1_col2, #T_53ef5_row1_col3, #T_53ef5_row1_col4, #T_53ef5_row1_col5, #T_53ef5_row1_col6, #T_53ef5_row1_col7, #T_53ef5_row3_col5, #T_53ef5_row3_col6, #T_53ef5_row3_col7, #T_53ef5_row4_col0, #T_53ef5_row4_col1, #T_53ef5_row4_col8, #T_53ef5_row4_col9, #T_53ef5_row7_col1, #T_53ef5_row7_col8, #T_53ef5_row7_col9, #T_53ef5_row8_col1, #T_53ef5_row8_col9, #T_53ef5_row12_col9, #T_53ef5_row16_col1, #T_53ef5_row16_col9, #T_53ef5_row19_col0, #T_53ef5_row19_col1, #T_53ef5_row19_col8, #T_53ef5_row19_col9 {
#   background-color: #f0f1f2;
#   color: #000000;
# }
# #T_53ef5_row1_col8 {
#   background-color: #8799e5;
#   color: #f1f1f1;
# }
# #T_53ef5_row1_col9, #T_53ef5_row13_col4, #T_53ef5_row16_col6 {
#   background-color: #e4e6f1;
#   color: #000000;
# }
# #T_53ef5_row2_col0 {
#   background-color: #abb7ea;
#   color: #000000;
# }
# #T_53ef5_row2_col1 {
#   background-color: #d6dbef;
#   color: #000000;
# }
# #T_53ef5_row2_col2, #T_53ef5_row6_col0, #T_53ef5_row13_col9 {
#   background-color: #d9deef;
#   color: #000000;
# }
# #T_53ef5_row2_col3, #T_53ef5_row9_col2, #T_53ef5_row11_col6 {
#   background-color: #e7e9f1;
#   color: #000000;
# }
# #T_53ef5_row2_col4, #T_53ef5_row3_col9, #T_53ef5_row13_col1, #T_53ef5_row19_col3 {
#   background-color: #e5e7f1;
#   color: #000000;
# }
# #T_53ef5_row2_col8 {
#   background-color: #8497e5;
#   color: #f1f1f1;
# }
# #T_53ef5_row2_col9, #T_53ef5_row8_col6, #T_53ef5_row13_col3 {
#   background-color: #dde0f0;
#   color: #000000;
# }
# #T_53ef5_row3_col0, #T_53ef5_row3_col8, #T_53ef5_row4_col4, #T_53ef5_row8_col2, #T_53ef5_row9_col1, #T_53ef5_row11_col9, #T_53ef5_row13_col7, #T_53ef5_row16_col3, #T_53ef5_row16_col5, #T_53ef5_row19_col6 {
#   background-color: #778ce4;
#   color: #f1f1f1;
# }
# #T_53ef5_row3_col1 {
#   background-color: #d6daef;
#   color: #000000;
# }
# #T_53ef5_row3_col2, #T_53ef5_row8_col7, #T_53ef5_row12_col7 {
#   background-color: #ebecf2;
#   color: #000000;
# }
# #T_53ef5_row3_col4, #T_53ef5_row5_col1, #T_53ef5_row5_col8, #T_53ef5_row7_col0, #T_53ef5_row9_col6, #T_53ef5_row12_col0, #T_53ef5_row13_col8, #T_53ef5_row14_col5, #T_53ef5_row15_col1, #T_53ef5_row15_col9, #T_53ef5_row16_col0, #T_53ef5_row17_col8, #T_53ef5_row18_col6, #T_53ef5_row18_col7 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_53ef5_row4_col2, #T_53ef5_row15_col4, #T_53ef5_row17_col3 {
#   background-color: #99a8e8;
#   color: #f1f1f1;
# }
# #T_53ef5_row4_col3, #T_53ef5_row13_col6 {
#   background-color: #e0e3f0;
#   color: #000000;
# }
# #T_53ef5_row4_col5, #T_53ef5_row10_col6, #T_53ef5_row13_col0 {
#   background-color: #ecedf2;
#   color: #000000;
# }
# #T_53ef5_row4_col6 {
#   background-color: #a2b0e9;
#   color: #000000;
# }
# #T_53ef5_row5_col2 {
#   background-color: #d1d7ee;
#   color: #000000;
# }
# #T_53ef5_row5_col3 {
#   background-color: #ced4ee;
#   color: #000000;
# }
# #T_53ef5_row5_col4 {
#   background-color: #cbd1ee;
#   color: #000000;
# }
# #T_53ef5_row5_col5, #T_53ef5_row14_col3 {
#   background-color: #e8e9f1;
#   color: #000000;
# }
# #T_53ef5_row5_col6 {
#   background-color: #7c90e4;
#   color: #f1f1f1;
# }
# #T_53ef5_row5_col9, #T_53ef5_row8_col0, #T_53ef5_row9_col4, #T_53ef5_row10_col7, #T_53ef5_row11_col5, #T_53ef5_row11_col7, #T_53ef5_row14_col7, #T_53ef5_row15_col5, #T_53ef5_row15_col8, #T_53ef5_row17_col0, #T_53ef5_row18_col2, #T_53ef5_row18_col3, #T_53ef5_row18_col4 {
#   background-color: #edeef2;
#   color: #000000;
# }
# #T_53ef5_row6_col1, #T_53ef5_row9_col9 {
#   background-color: #c8cfed;
#   color: #000000;
# }
# #T_53ef5_row6_col2 {
#   background-color: #d0d6ee;
#   color: #000000;
# }
# #T_53ef5_row6_col3 {
#   background-color: #bec7ec;
#   color: #000000;
# }
# #T_53ef5_row6_col4, #T_53ef5_row11_col8, #T_53ef5_row14_col2, #T_53ef5_row15_col0 {
#   background-color: #e1e4f0;
#   color: #000000;
# }
# #T_53ef5_row6_col5 {
#   background-color: #d2d8ef;
#   color: #000000;
# }
# #T_53ef5_row6_col6, #T_53ef5_row12_col3 {
#   background-color: #c7ceed;
#   color: #000000;
# }
# #T_53ef5_row6_col7, #T_53ef5_row7_col3, #T_53ef5_row11_col4, #T_53ef5_row14_col6 {
#   background-color: #eaebf1;
#   color: #000000;
# }
# #T_53ef5_row6_col8, #T_53ef5_row15_col7 {
#   background-color: #ebedf2;
#   color: #000000;
# }
# #T_53ef5_row6_col9 {
#   background-color: #cfd5ee;
#   color: #000000;
# }
# #T_53ef5_row7_col4, #T_53ef5_row17_col2, #T_53ef5_row17_col4 {
#   background-color: #a3b0e9;
#   color: #000000;
# }
# #T_53ef5_row7_col6 {
#   background-color: #8899e6;
#   color: #f1f1f1;
# }
# #T_53ef5_row8_col3 {
#   background-color: #92a3e7;
#   color: #f1f1f1;
# }
# #T_53ef5_row8_col4 {
#   background-color: #9baae8;
#   color: #000000;
# }
# #T_53ef5_row8_col5 {
#   background-color: #cdd3ee;
#   color: #000000;
# }
# #T_53ef5_row9_col0 {
#   background-color: #a4b1e9;
#   color: #000000;
# }
# #T_53ef5_row9_col8 {
#   background-color: #d4d9ef;
#   color: #000000;
# }
# #T_53ef5_row10_col0 {
#   background-color: #91a1e7;
#   color: #f1f1f1;
# }
# #T_53ef5_row10_col2 {
#   background-color: #a6b3e9;
#   color: #000000;
# }
# #T_53ef5_row10_col3 {
#   background-color: #c5cded;
#   color: #000000;
# }
# #T_53ef5_row10_col4, #T_53ef5_row18_col8 {
#   background-color: #889ae6;
#   color: #f1f1f1;
# }
# #T_53ef5_row10_col5 {
#   background-color: #e2e5f0;
#   color: #000000;
# }
# #T_53ef5_row10_col8 {
#   background-color: #c4cced;
#   color: #000000;
# }
# #T_53ef5_row11_col0, #T_53ef5_row16_col4 {
#   background-color: #e3e6f1;
#   color: #000000;
# }
# #T_53ef5_row11_col1 {
#   background-color: #c3cbed;
#   color: #000000;
# }
# #T_53ef5_row11_col2 {
#   background-color: #dce0f0;
#   color: #000000;
# }
# #T_53ef5_row11_col3 {
#   background-color: #e4e7f1;
#   color: #000000;
# }
# #T_53ef5_row12_col2 {
#   background-color: #b9c3ec;
#   color: #000000;
# }
# #T_53ef5_row12_col4 {
#   background-color: #a9b5ea;
#   color: #000000;
# }
# #T_53ef5_row12_col5 {
#   background-color: #e1e3f0;
#   color: #000000;
# }
# #T_53ef5_row12_col6 {
#   background-color: #9aa9e8;
#   color: #000000;
# }
# #T_53ef5_row13_col2 {
#   background-color: #e6e8f1;
#   color: #000000;
# }
# #T_53ef5_row13_col5 {
#   background-color: #d5daef;
#   color: #000000;
# }
# #T_53ef5_row14_col0 {
#   background-color: #dadef0;
#   color: #000000;
# }
# #T_53ef5_row14_col1 {
#   background-color: #b2bdeb;
#   color: #000000;
# }
# #T_53ef5_row14_col4 {
#   background-color: #e9eaf1;
#   color: #000000;
# }
# #T_53ef5_row14_col8 {
#   background-color: #d7dcef;
#   color: #000000;
# }
# #T_53ef5_row14_col9 {
#   background-color: #8c9de6;
#   color: #f1f1f1;
# }
# #T_53ef5_row15_col2 {
#   background-color: #aab6ea;
#   color: #000000;
# }
# #T_53ef5_row15_col3 {
#   background-color: #e8eaf1;
#   color: #000000;
# }
# #T_53ef5_row15_col6 {
#   background-color: #92a2e7;
#   color: #f1f1f1;
# }
# #T_53ef5_row16_col2 {
#   background-color: #dbdff0;
#   color: #000000;
# }
# #T_53ef5_row16_col7 {
#   background-color: #e9ebf1;
#   color: #000000;
# }
# #T_53ef5_row17_col5, #T_53ef5_row18_col1 {
#   background-color: #d9ddef;
#   color: #000000;
# }
# #T_53ef5_row17_col6 {
#   background-color: #cad1ee;
#   color: #000000;
# }
# #T_53ef5_row17_col7 {
#   background-color: #e2e5f1;
#   color: #000000;
# }
# #T_53ef5_row18_col0 {
#   background-color: #b0bbea;
#   color:

# %%
(_,_), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

img = test_images[2004]
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

plt.imshow(img, cmap='viridis')
plt.axis('off')
plt.show()

# %%
# Extracts the outputs of the top 8 layers:
layer_outputs = [layer.output for layer in model.layers[:8]]
# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(img_tensor)
len(activations)
# Out:
# 8

# %%
layer_names = []
for layer in model.layers:
    layer_names.append(layer.name)
    
layer_names
# Out:
# ['conv2d_3',
#  'max_pooling2d_3',
#  'dropout_3',
#  'conv2d_4',
#  'max_pooling2d_4',
#  'dropout_4',
#  'conv2d_5',
#  'max_pooling2d_5',
#  'dropout_5',
#  'flatten_1',
#  'batch_normalization_1',
#  'dense_2',
#  'dense_3']

# %%
# These are the names of the layers, so can have them as part of our plot
layer_names = []
for layer in model.layers[:3]:
    layer_names.append(layer.name)

images_per_row = 16

# Now let's display our feature maps
for layer_name, layer_activation in zip(layer_names, activations):
    # This is the number of features in the feature map
    n_features = layer_activation.shape[-1]

    # The feature map has shape (1, size, size, n_features)
    size = layer_activation.shape[1]

    # We will tile the activation channels in this matrix
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))

    # We'll tile each filter into this big horizontal grid
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            # Post-process the feature to make it visually palatable
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
                         row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide

# %%
# Extracts the outputs of all layers:
layer_outputs = [layer.output for layer in model.layers]

# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# Get activation values for the last dense layer
activations = activation_model.predict(x_valid_norm[:5000])
dense_layer_activations = activations[-3]
output_layer_activations = activations[-1]

# %% [markdown]
# sklearn.manifold.TSNE

# %%
# Reduce the dimension using T-SNE to visualize i n a scatterplot
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(dense_layer_activations)

# Scaling
tsne_results = (tsne_results - tsne_results.min()) / (tsne_results.max() - tsne_results.min())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.011s...
# [t-SNE] Computed neighbors for 5000 samples in 1.687s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 2.074841
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.710899
# [t-SNE] KL divergence after 300 iterations: 2.716166

# %%
cmap = plt.cm.tab10
plt.figure(figsize=(16,10))
scatter = plt.scatter(tsne_results[:,0],tsne_results[:,1], c=y_valid_split[:5000], s=10, cmap=cmap)
plt.legend(handles=scatter.legend_elements()[0], labels=class_names)

image_positions = np.array([[1., 1.]])
for index, position in enumerate(tsne_results):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.02: # if far enough from other images
        image_positions = np.r_[image_positions, [position]]
        imagebox = mpl.offsetbox.AnnotationBbox(
            mpl.offsetbox.OffsetImage(x_train[index], cmap="binary"),
            position, bboxprops={"lw": 1})
        plt.gca().add_artist(imagebox)
plt.axis("off")
plt.show()
