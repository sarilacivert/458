# %% [markdown]
# A2a Research Assignment 02 - Part 1
#
# Import packages needed

# %%
import datetime
import time
import numpy as np
import pandas as pd
from packaging import version
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.7.0

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.7.0

# %% [markdown]
# Mount Google Drive to Colab Environment

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %% [markdown]
# Functions for Research Assignment

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# Loading cifar10 Dataset
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %% [markdown]
# Tuple of Numpy arrays: (x_train, y_train), (x_test, y_test).
#
# x_train, x_test: uint8 arrays of color image data with shapes (num_samples, 32, 32).
#
# y_train, y_test: uint8 arrays of digit labels (integers in range 0-9)
#
# EDA Training and Test Datasets
#
# Imported 50000 examples for training and 10000 examples for test
#
# Imported 50000 labels for training and 10000 labels for test

# %%
print('train_images:\t{}'.format(x_train.shape))
print('train_labels:\t{}'.format(y_train.shape))
print('test_images:\t\t{}'.format(x_test.shape))
print('test_labels:\t\t{}'.format(y_test.shape))
# Out:
# train_images:	(50000, 32, 32, 3)
# train_labels:	(50000, 1)
# test_images:		(10000, 32, 32, 3)
# test_labels:		(10000, 1)

# %% [markdown]
# Review labels for training dataset

# %%
print("First ten labels training dataset:\n {}\n".format(y_train[0:10]))
print("This output the numeric label, need to convert to item description")
# Out:
# First ten labels training dataset:
#  [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]
#
# This output the numeric label, need to convert to item description

# %% [markdown]
# Plot Examples

# %%
def get_three_classes(x, y):
    def indices_of(class_id):
        indices, _ = np.where(y == float(class_id))
        return indices

    indices = np.concatenate([indices_of(0), indices_of(1), indices_of(2)], axis=0)
    
    x = x[indices]
    y = y[indices]
    
    count = x.shape[0]
    indices = np.random.choice(range(count), count, replace=False)
    
    x = x[indices]
    y = y[indices]
    
    y = tf.keras.utils.to_categorical(y)
    
    return x, y

# %%
(train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %%
x_preview, y_preview = get_three_classes(train_images, train_labels)
x_preview, y_preview = get_three_classes(test_images, test_labels)

# %%
class_names_preview = ['aeroplane', 'car', 'bird']

def show_random_examples(x, y, p):
    indices = np.random.choice(range(x.shape[0]), 10, replace=False)
    
    x = x[indices]
    y = y[indices]
    p = p[indices]
    
    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(class_names_preview[np.argmax(p[i])], color=col)
    plt.show()

show_random_examples(x_preview, y_preview, y_preview)

# %% [markdown]
# Preprocessing Data for Model Development
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# Label	Class_
#
# 0	airplane
#
# 1	automobile
#
# 2	bird
#
# 3	cat
#
# 4	deer
#
# 5	dog
#
# 6	frog
#
# 7	horse
#
# 8	ship
#
# 9	truck

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

# %% [markdown]
# Create Validation Data Set

# %%
x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(x_train
                                                                              ,y_train
                                                                              ,test_size=.1
                                                                              ,random_state=42
                                                                              ,shuffle=True)

# %% [markdown]
# Confirm Datasets {Train, Validation, Test}

# %%
print(x_train_split.shape, x_valid_split.shape, x_test.shape)
# Out:
# (45000, 32, 32, 3) (5000, 32, 32, 3) (10000, 32, 32, 3)

# %% [markdown]
# Rescale Examples {Train, Validation, Test}
#
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255
#
# Each element in each example is a pixel value
#
# Pixel values range from 0 to 255
#
# 0 = black
#
# 255 = white

# %%
x_train_norm = x_train_split/255

x_valid_norm = x_valid_split/255

x_test_norm = x_test/255

# %% [markdown]
# Build CNN Model
#
# We use a Sequential class defined in Keras to create our model.
#
# The first 9 layers Conv2D MaxPooling, Dropout handle feature learning.
#
# The last 3 layers, handle classification

# %%
model = models.Sequential()
model.add(layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu,input_shape=(32, 32, 3)))
model.add(layers.MaxPool2D((2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Flatten())
model.add(layers.BatchNormalization())
model.add(layers.Dense(units=384, activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.L2(0.001)))
model.add(layers.Dense(units=10, activation=tf.nn.softmax))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 30, 30, 128)       3584
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 15, 15, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       295168
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dense_2 (Dense)             (None, 384)               786816
#
#  dense_3 (Dense)             (None, 10)                3850
#
# =================================================================
# Total params: 2,277,770
# Trainable params: 2,273,674
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "CIFAR10.png", show_shapes=True)

# %% [markdown]
# **Compiling the model**
#
# In addition to setting up our model architecture, we also need to define which algorithm should the model use in order to optimize the weights and biases as per the given data. We will use stochastic gradient descent.
#
# We also need to define a loss function. Think of this function as the difference between the predicted outputs and the actual outputs given in the dataset. This loss needs to be minimised in order to have a higher model accuracy. That's what the optimization algorithm essentially does - it minimises the loss during model training. For our multi-class classification problem, categorical cross entropy is commonly used.
#
# Finally, we will use the accuracy during training as a metric to keep track of as the model trains.

# %%
model.compile(optimizer='Nadam', 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
history = model.fit(x_train_norm
                    ,y_train_split
                    ,epochs=200
                    ,batch_size=512
                    ,validation_data=(x_valid_norm, y_valid_split)
                    ,callbacks=[
                    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
                    tf.keras.callbacks.ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/models/model_{val_accuracy:.4f}.h5', save_best_only=True,
                                        save_weights_only=False, monitor='val_accuracy')]                                                                                                           
                   )
# Out:
# Epoch 1/200
# 88/88 [==============================] - 5s 44ms/step - loss: 2.1070 - accuracy: 0.4248 - val_loss: 2.5416 - val_accuracy: 0.4602
# Epoch 2/200
# 88/88 [==============================] - 4s 41ms/step - loss: 1.4753 - accuracy: 0.5889 - val_loss: 2.2220 - val_accuracy: 0.5396
# Epoch 3/200
# 88/88 [==============================] - 4s 42ms/step - loss: 1.1981 - accuracy: 0.6598 - val_loss: 1.9262 - val_accuracy: 0.6512
# Epoch 4/200
# 88/88 [==============================] - 4s 40ms/step - loss: 1.0371 - accuracy: 0.6980 - val_loss: 1.5516 - val_accuracy: 0.6510
# Epoch 5/200
# 88/88 [==============================] - 3s 39ms/step - loss: 0.9220 - accuracy: 0.7291 - val_loss: 1.1686 - val_accuracy: 0.7266
# Epoch 6/200
# 88/88 [==============================] - 3s 38ms/step - loss: 0.8320 - accuracy: 0.7551 - val_loss: 0.9308 - val_accuracy: 0.7428
# Epoch 7/200
# 88/88 [==============================] - 3s 38ms/step - loss: 0.7717 - accuracy: 0.7739 - val_loss: 0.8257 - val_accuracy: 0.7618
# Epoch 8/200
# 88/88 [==============================] - 3s 38ms/step - loss: 0.7168 - accuracy: 0.7894 - val_loss: 0.8090 - val_accuracy: 0.7622
# Epoch 9/200
# 88/88 [==============================] - 3s 37ms/step - loss: 0.6761 - accuracy: 0.8067 - val_loss: 0.8181 - val_accuracy: 0.7620
# Epoch 10/200
# 88/88 [==============================] - 3s 37ms/step - loss: 0.6411 - accuracy: 0.8164 - val_loss: 0.9285 - val_accuracy: 0.7280
# Epoch 11/200
# 88/88 [==============================] - 3s 38ms/step - loss: 0.6117 - accuracy: 0.8282 - val_loss: 0.7810 - val_accuracy: 0.7774
# Epoch 12/200
# 88/88 [==============================] - 3s 39ms/step - loss: 0.5742 - accuracy: 0.8410 - val_loss: 0.7439 - val_accuracy: 0.7884
# Epoch 13/200
# 88/88 [==============================] - 3s 37ms/step - loss: 0.5665 - accuracy: 0.8450 - val_loss: 0.7657 - val_accuracy: 0.7820
# Epoch 14/200
# 88/88 [==============================] - 3s 38ms/step - loss: 0.5479 - accuracy: 0.8534 - val_loss: 0.7370 - val_accuracy: 0.7988
# Epoch 15/200
# 88/88 [==============================] - 3s 37ms/step - loss: 0.5249 - accuracy: 0.8622 - val_loss: 0.7671 - val_accuracy: 0.7894
# Epoch 16/200
# 88/88 [==============================] - 3s 38ms/step - loss: 0.5047 - accuracy: 0.8689 - val_loss: 0.7137 - val_accuracy: 0.8086
# Epoch 17/200
# 88/88 [==============================] - 3s 40ms/step - loss: 0.4927 - accuracy: 0.8732 - val_loss: 0.8148 - val_accuracy: 0.7842
# Epoch 18/200
# 88/88 [==============================] - 3s 39ms/step - loss: 0.4804 - accuracy: 0.8778 - val_loss: 0.8058 - val_accuracy: 0.7840
# Epoch 19/200
# 88/88 [==============================] - 3s 38ms/step - loss: 0.4612 - accuracy: 0.8852 - val_loss: 0.7334 - val_accuracy: 0.8076

# %% [markdown]
# **Validation Data**
#
# Data on which to evaluate the loss and any model metrics at the end of each epoch
#
# The model will not be trained on this data
#
# **Evaluate the model**
#
# In order to ensure that this is not a simple "memorization" by the machine, we should evaluate the performance on the test set.
#
# This is easy to do, we simply use the evaluate method on our model.

# %%
loss, accuracy = model.evaluate(x_test_norm, y_test)
print('test set accuracy: ', accuracy * 100)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.7842 - accuracy: 0.7917
# test set accuracy:  79.1700005531311

# %% [markdown]
# **Predictions**

# %%
preds = model.predict(x_test_norm)
print('shape of preds: ', preds.shape)
# Out:
# shape of preds:  (10000, 10)

# %% [markdown]
# **Plotting Performance Metrics**
#
# We use Matplotlib to create 2 plots--displaying the training and validation loss (resp. accuracy) for each (training) epoch side by side.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#      loss  accuracy  val_loss  val_accuracy
# 14  0.525     0.862     0.767         0.789
# 15  0.505     0.869     0.714         0.809
# 16  0.493     0.873     0.815         0.784
# 17  0.480     0.878     0.806         0.784
# 18  0.461     0.885     0.733         0.808

# %%
losses = history.history['loss']
accs = history.history['accuracy']
val_losses = history.history['val_loss']
val_accs = history.history['val_accuracy']
epochs = len(losses)

# %%
plt.figure(figsize=(16, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# Confusion matrices
#
# Using both sklearn.metrics. Then we visualize the confusion matrix and see what that tells us.

# %%
pred1= model.predict(x_test_norm)
pred1=np.argmax(pred1, axis=1)

# %%
print_validation_report(y_test, pred1)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80      1000
#            1       0.91      0.89      0.90      1000
#            2       0.76      0.67      0.71      1000
#            3       0.59      0.71      0.65      1000
#            4       0.85      0.68      0.75      1000
#            5       0.67      0.77      0.72      1000
#            6       0.86      0.83      0.85      1000
#            7       0.87      0.80      0.83      1000
#            8       0.86      0.88      0.87      1000
#            9       0.92      0.80      0.85      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.80      0.79      0.79     10000
# weighted avg       0.80      0.79      0.79     10000
#
# Accuracy Score: 0.7917
# Root Mean Square Error: 1.8512698344649816

# %%
plot_confusion_matrix(y_test,pred1)

# %% [markdown]
# Load HDF5 Model Format

# %%
model = tf.keras.models.load_model('/content/gdrive/My Drive/Colab Notebooks/models/model_0.7774.h5')

# %%
preds = model.predict(x_test_norm)

preds.shape
# Out:
# (10000, 10)

# %% [markdown]
# **Predictions**

# %%
cm = sns.light_palette((260, 75, 60), input="husl", as_cmap=True)

df = pd.DataFrame(preds[0:20], columns = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])
df.style.format("{:.2%}").background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_f8ad6_row0_col0, #T_f8ad6_row5_col2, #T_f8ad6_row5_col5, #T_f8ad6_row7_col5, #T_f8ad6_row14_col8, #T_f8ad6_row16_col2, #T_f8ad6_row17_col6 {
#   background-color: #f0f0f2;
#   color: #000000;
# }
# #T_f8ad6_row0_col1, #T_f8ad6_row4_col3, #T_f8ad6_row10_col3, #T_f8ad6_row11_col1, #T_f8ad6_row12_col7, #T_f8ad6_row16_col3 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_f8ad6_row0_col2, #T_f8ad6_row0_col5, #T_f8ad6_row1_col0, #T_f8ad6_row2_col0, #T_f8ad6_row3_col4, #T_f8ad6_row7_col3, #T_f8ad6_row15_col4 {
#   background-color: #ecedf2;
#   color: #000000;
# }
# #T_f8ad6_row0_col3 {
#   background-color: #8395e5;
#   color: #f1f1f1;
# }
# #T_f8ad6_row0_col4, #T_f8ad6_row0_col7, #T_f8ad6_row0_col9, #T_f8ad6_row1_col2, #T_f8ad6_row1_col3, #T_f8ad6_row1_col4, #T_f8ad6_row1_col5, #T_f8ad6_row1_col6, #T_f8ad6_row1_col7, #T_f8ad6_row1_col9, #T_f8ad6_row2_col2, #T_f8ad6_row2_col3, #T_f8ad6_row2_col4, #T_f8ad6_row2_col5, #T_f8ad6_row2_col6, #T_f8ad6_row2_col7, #T_f8ad6_row3_col1, #T_f8ad6_row3_col3, #T_f8ad6_row3_col5, #T_f8ad6_row3_col6, #T_f8ad6_row3_col7, #T_f8ad6_row3_col9, #T_f8ad6_row4_col0, #T_f8ad6_row4_col1, #T_f8ad6_row4_col5, #T_f8ad6_row4_col7, #T_f8ad6_row4_col8, #T_f8ad6_row4_col9, #T_f8ad6_row5_col0, #T_f8ad6_row5_col1, #T_f8ad6_row5_col3, #T_f8ad6_row5_col4, #T_f8ad6_row5_col7, #T_f8ad6_row5_col8, #T_f8ad6_row5_col9, #T_f8ad6_row6_col0, #T_f8ad6_row6_col2, #T_f8ad6_row6_col3, #T_f8ad6_row6_col4, #T_f8ad6_row6_col5, #T_f8ad6_row6_col6, #T_f8ad6_row6_col7, #T_f8ad6_row6_col8, #T_f8ad6_row6_col9, #T_f8ad6_row7_col0, #T_f8ad6_row7_col1, #T_f8ad6_row7_col7, #T_f8ad6_row7_col8, #T_f8ad6_row7_col9, #T_f8ad6_row8_col0, #T_f8ad6_row8_col1, #T_f8ad6_row8_col6, #T_f8ad6_row8_col7, #T_f8ad6_row8_col8, #T_f8ad6_row8_col9, #T_f8ad6_row9_col0, #T_f8ad6_row9_col2, #T_f8ad6_row9_col3, #T_f8ad6_row9_col4, #T_f8ad6_row9_col5, #T_f8ad6_row9_col6, #T_f8ad6_row9_col7, #T_f8ad6_row9_col8, #T_f8ad6_row10_col1, #T_f8ad6_row10_col6, #T_f8ad6_row10_col9, #T_f8ad6_row11_col0, #T_f8ad6_row11_col2, #T_f8ad6_row11_col3, #T_f8ad6_row11_col4, #T_f8ad6_row11_col5, #T_f8ad6_row11_col6, #T_f8ad6_row11_col7, #T_f8ad6_row11_col8, #T_f8ad6_row12_col0, #T_f8ad6_row12_col1, #T_f8ad6_row12_col8, #T_f8ad6_row12_col9, #T_f8ad6_row13_col0, #T_f8ad6_row13_col1, #T_f8ad6_row13_col2, #T_f8ad6_row13_col3, #T_f8ad6_row13_col4, #T_f8ad6_row13_col5, #T_f8ad6_row13_col6, #T_f8ad6_row13_col8, #T_f8ad6_row13_col9, #T_f8ad6_row14_col0, #T_f8ad6_row14_col2, #T_f8ad6_row14_col3, #T_f8ad6_row14_col4, #T_f8ad6_row14_col5, #T_f8ad6_row14_col6, #T_f8ad6_row14_col7, #T_f8ad6_row15_col1, #T_f8ad6_row15_col5, #T_f8ad6_row15_col7, #T_f8ad6_row15_col9, #T_f8ad6_row16_col0, #T_f8ad6_row16_col1, #T_f8ad6_row16_col4, #T_f8ad6_row16_col6, #T_f8ad6_row16_col7, #T_f8ad6_row16_col8, #T_f8ad6_row16_col9, #T_f8ad6_row17_col0, #T_f8ad6_row17_col1, #T_f8ad6_row17_col8, #T_f8ad6_row17_col9, #T_f8ad6_row18_col0, #T_f8ad6_row18_col1, #T_f8ad6_row18_col2, #T_f8ad6_row18_col3, #T_f8ad6_row18_col4, #T_f8ad6_row18_col5, #T_f8ad6_row18_col6, #T_f8ad6_row18_col7, #T_f8ad6_row18_col9, #T_f8ad6_row19_col0, #T_f8ad6_row19_col1, #T_f8ad6_row19_col2, #T_f8ad6_row19_col3, #T_f8ad6_row19_col4, #T_f8ad6_row19_col5, #T_f8ad6_row19_col7, #T_f8ad6_row19_col8, #T_f8ad6_row19_col9 {
#   background-color: #f0f1f2;
#   color: #000000;
# }
# #T_f8ad6_row0_col6, #T_f8ad6_row8_col4, #T_f8ad6_row15_col8, #T_f8ad6_row17_col3 {
#   background-color: #e7e9f1;
#   color: #000000;
# }
# #T_f8ad6_row0_col8, #T_f8ad6_row8_col5 {
#   background-color: #ebecf2;
#   color: #000000;
# }
# #T_f8ad6_row1_col1 {
#   background-color: #a6b2e9;
#   color: #000000;
# }
# #T_f8ad6_row1_col8 {
#   background-color: #c5cded;
#   color: #000000;
# }
# #T_f8ad6_row2_col1 {
#   background-color: #b5bfeb;
#   color: #000000;
# }
# #T_f8ad6_row2_col8, #T_f8ad6_row4_col6 {
#   background-color: #b7c1eb;
#   color: #000000;
# }
# #T_f8ad6_row2_col9, #T_f8ad6_row14_col1, #T_f8ad6_row15_col3 {
#   background-color: #efeff2;
#   color: #000000;
# }
# #T_f8ad6_row3_col0, #T_f8ad6_row4_col4, #T_f8ad6_row6_col1, #T_f8ad6_row7_col2, #T_f8ad6_row8_col3, #T_f8ad6_row11_col9, #T_f8ad6_row13_col7, #T_f8ad6_row16_col5, #T_f8ad6_row18_col8, #T_f8ad6_row19_col6 {
#   background-color: #778ce4;
#   color: #f1f1f1;
# }
# #T_f8ad6_row3_col2, #T_f8ad6_row10_col4 {
#   background-color: #d4d9ef;
#   color: #000000;
# }
# #T_f8ad6_row3_col8, #T_f8ad6_row9_col9 {
#   background-color: #edeef2;
#   color: #000000;
# }
# #T_f8ad6_row4_col2 {
#   background-color: #d3d8ef;
#   color: #000000;
# }
# #T_f8ad6_row5_col6 {
#   background-color: #788ce4;
#   color: #f1f1f1;
# }
# #T_f8ad6_row7_col4 {
#   background-color: #cad1ee;
#   color: #000000;
# }
# #T_f8ad6_row7_col6 {
#   background-color: #9caae8;
#   color: #000000;
# }
# #T_f8ad6_row8_col2 {
#   background-color: #e8eaf1;
#   color: #000000;
# }
# #T_f8ad6_row9_col1 {
#   background-color: #7a8ee4;
#   color: #f1f1f1;
# }
# #T_f8ad6_row10_col0 {
#   background-color: #92a2e7;
#   color: #f1f1f1;
# }
# #T_f8ad6_row10_col2 {
#   background-color: #dbdff0;
#   color: #000000;
# }
# #T_f8ad6_row10_col5, #T_f8ad6_row10_col7, #T_f8ad6_row15_col0 {
#   background-color: #eeeff2;
#   color: #000000;
# }
# #T_f8ad6_row10_col8, #T_f8ad6_row12_col6 {
#   background-color: #e5e7f1;
#   color: #000000;
# }
# #T_f8ad6_row12_col2 {
#   background-color: #90a0e7;
#   color: #f1f1f1;
# }
# #T_f8ad6_row12_col3 {
#   background-color: #e4e7f1;
#   color: #000000;
# }
# #T_f8ad6_row12_col4 {
#   background-color: #9cabe8;
#   color: #000000;
# }
# #T_f8ad6_row12_col5 {
#   background-color: #c2caed;
#   color: #000000;
# }
# #T_f8ad6_row14_col9 {
#   background-color: #788de4;
#   color: #f1f1f1;
# }
# #T_f8ad6_row15_col2 {
#   background-color: #dfe2f0;
#   color: #000000;
# }
# #T_f8ad6_row15_col6 {
#   background-color: #8799e6;
#   color: #f1f1f1;
# }
# #T_f8ad6_row17_col2 {
#   background-color: #bac4ec;
#   color: #000000;
# }
# #T_f8ad6_row17_col4 {
#   background-color: #e1e3f0;
#   color: #000000;
# }
# #T_f8ad6_row17_col5 {
#   background-color: #ebedf2;
#   color: #000000;
# }
# #T_f8ad6_row17_col7 {
#   background-color: #93a3e7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f8ad6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >airplane</th>
#       <th class="col_heading level0 col1" >automobile</th>
#       <th class="col_heading level0 col2" >bird</th>
#       <th class="col_heading level0 col3" >cat</th>
#       <th class="col_heading level0 col4" >deer</th>
#       <th class="col_heading level0 col5" >dog</th>
#       <th class="col_heading level0 col6" >frog</th>
#       <th class="col_heading level0 col7" >horse</th>
#       <th class="col_heading level0 col8" >ship</th>
#       <th class="col_heading level0 col9" >truck</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8ad6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8ad6_row0_col0" class="data row0 col0" >0.41%</td>
#       <td id="T_f8ad6_row0_col1" class="data row0 col1" >1.04%</td>
#       <td id="T_f8ad6_row0_col2" class="data row0 col2" >0.40%</td>
#       <td id="T_f8ad6_row0_col3" class="data row0 col3" >81.30%</td>
#       <td id="T_f8ad6_row0_col4" class="data row0 col4" >0.07%</td>
#       <td id="T_f8ad6_row0_col5" class="data row0 col5" >3.79%</td>
#       <td id="T_f8ad6_row0_col6" class="data row0 col6" >7.90%</td>
#       <td id="T_f8ad6_row0_col7" class="data row0 col7" >0.32%</td>
#       <td id="T_f8ad6_row0_col8" class="data row0 col8" >4.71%</td>
#       <td id="T_f8ad6_row0_col9" class="data row0 col9" >0.06%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ad6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8ad6_row1_col0" class="data row1 col0" >3.29%</td>
#       <td id="T_f8ad6_row1_col1" class="data row1 col1" >61.33%</td>
#       <td id="T_f8ad6_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_f8ad6_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_f8ad6_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_f8ad6_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_f8ad6_row1_col6" class="data row1 col6" >0.00%</td>
#       <td id="T_f8ad6_row1_col7" class="data row1 col7" >

# %%
(_,_), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

img = test_images[2004]
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

plt.imshow(img, cmap='viridis')
plt.axis('off')
plt.show()

# %%
# Extracts the outputs of the top 8 layers:
layer_outputs = [layer.output for layer in model.layers[:8]]
# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(img_tensor)
len(activations)
# Out:
# 8

# %%
layer_names = []
for layer in model.layers:
    layer_names.append(layer.name)
    
layer_names
# Out:
# ['conv2d_3',
#  'max_pooling2d_3',
#  'dropout_3',
#  'conv2d_4',
#  'max_pooling2d_4',
#  'dropout_4',
#  'conv2d_5',
#  'max_pooling2d_5',
#  'dropout_5',
#  'flatten_1',
#  'batch_normalization_1',
#  'dense_2',
#  'dense_3']

# %%
# These are the names of the layers, so can have them as part of our plot
layer_names = []
for layer in model.layers[:3]:
    layer_names.append(layer.name)

images_per_row = 16

# Now let's display our feature maps
for layer_name, layer_activation in zip(layer_names, activations):
    # This is the number of features in the feature map
    n_features = layer_activation.shape[-1]

    # The feature map has shape (1, size, size, n_features)
    size = layer_activation.shape[1]

    # We will tile the activation channels in this matrix
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))

    # We'll tile each filter into this big horizontal grid
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            # Post-process the feature to make it visually palatable
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
                         row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide

# %%
# Extracts the outputs of all layers:
layer_outputs = [layer.output for layer in model.layers]

# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# Get activation values for the last dense layer
activations = activation_model.predict(x_valid_norm[:5000])
dense_layer_activations = activations[-3]
output_layer_activations = activations[-1]

# %% [markdown]
# sklearn.manifold.TSNE

# %%
# Reduce the dimension using T-SNE to visualize i n a scatterplot
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(dense_layer_activations)

# Scaling
tsne_results = (tsne_results - tsne_results.min()) / (tsne_results.max() - tsne_results.min())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.008s...
# [t-SNE] Computed neighbors for 5000 samples in 2.050s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 5.110817
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.865036
# [t-SNE] KL divergence after 300 iterations: 3.293222

# %%
cmap = plt.cm.tab10
plt.figure(figsize=(16,10))
scatter = plt.scatter(tsne_results[:,0],tsne_results[:,1], c=y_valid_split[:5000], s=10, cmap=cmap)
plt.legend(handles=scatter.legend_elements()[0], labels=class_names)

image_positions = np.array([[1., 1.]])
for index, position in enumerate(tsne_results):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.02: # if far enough from other images
        image_positions = np.r_[image_positions, [position]]
        imagebox = mpl.offsetbox.AnnotationBbox(
            mpl.offsetbox.OffsetImage(x_train[index], cmap="binary"),
            position, bboxprops={"lw": 1})
        plt.gca().add_artist(imagebox)
plt.axis("off")
plt.show()
